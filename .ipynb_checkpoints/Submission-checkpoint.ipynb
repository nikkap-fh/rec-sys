# %% [markdown]
# ## Advanced Seminar for Recognition System
# ##### Masashi Nakayama - Fall Semester 2025/26
# ### Jan Niklas Kappey (ID: 2568017)

# %% [markdown]
# **Create a linearly indistinguishable multi-class classification
# system using a multi-layer perceptron. Please present your
# findings, including any ingenuity you have used.**

# %%
import kagglehub
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, auc
from sklearn.model_selection import train_test_split

# Download latest version
path = kagglehub.dataset_download("drgfreeman/rockpaperscissors")

print("Path to dataset files:", path)
print(os.listdir(path))
# Out:
# 2026-01-21 07:14:52.333534: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-21 07:14:52.361500: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI AVX512_BF16, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Path to dataset files: /home/nikla/.cache/kagglehub/datasets/drgfreeman/rockpaperscissors/versions/2
# ['scissors', 'rock', 'README_rpc-cv-images.txt', 'rps-cv-images', 'paper']

# %%
import tensorflow as tf
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# GPUs: []

# %%
labels = ['paper','scissors','rock']

# %%
data_augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# %%
from keras.saving import register_keras_serializable

@register_keras_serializable()
class CNN(Model):
    def __init__(self, hidden_dim=512, output_dim=3):
        super().__init__()
        self.l1 = Conv2D(32, (3, 3), activation='relu')
        self.l2 = MaxPooling2D((2, 2))
        self.l3 = Conv2D(64, (3, 3), activation='relu')
        self.l4 = MaxPooling2D((2, 2))
        self.l5 = Flatten()
        self.l6 = Dense(hidden_dim, activation='relu')
        self.l7 = Dense(output_dim, activation='softmax')

        # Define the layer sequence you intended to iterate through
        self.ls = [self.l1, self.l2, self.l3, self.l4, self.l5, self.l6, self.l7]

    def call(self, x, training=False):
        if training:
            x = data_augment(x)
        for layer in self.ls:
            x = layer(x)
        return x

# %%
def input_target_split(root_dir, labels, image_size=(150, 150)):
    dataset = []
    for class_id, label in enumerate(labels):
        folder = os.path.join(root_dir, label)
        if not os.path.isdir(folder):
            raise FileNotFoundError(
                f"Couldn't find folder: {folder}\n"
                f"Check your dataset path. Top-level contents: {os.listdir(root_dir)}"
            )

        for fname in os.listdir(folder):
            fpath = os.path.join(folder, fname)
            img = load_img(fpath, target_size=image_size)
            img = img_to_array(img).astype("float32") / 255.0
            dataset.append((img, class_id))

    X, y = zip(*dataset)
    return np.array(X, dtype="float32"), np.array(y, dtype="int32")

# %%
X, y = input_target_split(path,labels)

# %%
# train / val / test split
x_train, x_tmp, t_train, t_tmp = train_test_split(
    X, y, test_size=0.3, random_state=1234, stratify=y)

x_val, x_test, t_val, t_test = train_test_split(
    x_tmp, t_tmp, test_size=0.67, random_state=1234, stratify=t_tmp)

# %%
n = len(labels)
model = CNN(hidden_dim=12, output_dim=n)

# IMPORTANT: use sparse loss/acc since labels are integers
criterion = losses.SparseCategoricalCrossentropy()
optimizer = optimizers.SGD(learning_rate=0.01)

train_loss = metrics.Mean(name="train_loss")
train_acc = metrics.SparseCategoricalAccuracy(name="train_acc")
val_acc = metrics.SparseCategoricalAccuracy(name="val_acc")

# %%
def compute_loss(t, y):
    return criterion(t, y)

@tf.function
def train_step(x, t):
    with tf.GradientTape() as tape:
        preds = model(x, training=True)
        loss = criterion(t, preds)
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    train_loss.update_state(loss)
    train_acc.update_state(t, preds)
    return loss

@tf.function
def test_step(x, t):
    preds = model(x, training=False)
    loss = criterion(t, preds)
    test_loss.update_state(loss)
    test_acc.update_state(t, preds)
    return loss
    
@tf.function
def val_step(x, t):
    preds = model(x, training=False)
    val_acc.update_state(t, preds)

# %%
epochs = 100
batch_size = 32
n_batches = x_train.shape[0] // batch_size

loss_history = []
acc_history = []

for epoch in range(epochs):
    # reset metrics EACH epoch (otherwise they accumulate across epochs)
    train_loss.reset_state()
    train_acc.reset_state()

    x_, t_ = shuffle(x_train, t_train, random_state=epoch)

    for batch in range(n_batches):
        start = batch * batch_size
        end = start + batch_size
        train_step(x_[start:end], t_[start:end])
        
    loss_history.append(train_loss.result().numpy())
    acc_history.append(train_acc.result().numpy())

    val_acc.reset_state()
    val_step(x_val, t_val)

    print(
    f"epoch: {epoch+1}, "
    f"loss: {train_loss.result():.3f}, "
    f"train_acc: {train_acc.result():.3f}, "
    f"val_acc: {val_acc.result():.3f}"
)
# Out:
# epoch: 1, loss: 1.100, train_acc: 0.351, val_acc: 0.333
# epoch: 2, loss: 1.089, train_acc: 0.399, val_acc: 0.556
# epoch: 3, loss: 1.078, train_acc: 0.439, val_acc: 0.500
# epoch: 4, loss: 1.047, train_acc: 0.465, val_acc: 0.542
# epoch: 5, loss: 0.998, train_acc: 0.495, val_acc: 0.588
# epoch: 6, loss: 0.961, train_acc: 0.501, val_acc: 0.579
# epoch: 7, loss: 0.935, train_acc: 0.543, val_acc: 0.574
# epoch: 8, loss: 0.899, train_acc: 0.541, val_acc: 0.653
# epoch: 9, loss: 0.835, train_acc: 0.606, val_acc: 0.528
# epoch: 10, loss: 0.764, train_acc: 0.633, val_acc: 0.704
# epoch: 11, loss: 0.709, train_acc: 0.662, val_acc: 0.620
# epoch: 12, loss: 0.715, train_acc: 0.677, val_acc: 0.681
# epoch: 13, loss: 0.703, train_acc: 0.684, val_acc: 0.736
# epoch: 14, loss: 0.662, train_acc: 0.698, val_acc: 0.616
# epoch: 15, loss: 0.642, train_acc: 0.724, val_acc: 0.676
# epoch: 16, loss: 0.622, train_acc: 0.723, val_acc: 0.685
# epoch: 17, loss: 0.634, train_acc: 0.730, val_acc: 0.847
# epoch: 18, loss: 0.592, train_acc: 0.747, val_acc: 0.870
# epoch: 19, loss: 0.592, train_acc: 0.758, val_acc: 0.833
# epoch: 20, loss: 0.587, train_acc: 0.752, val_acc: 0.866
# epoch: 21, loss: 0.543, train_acc: 0.776, val_acc: 0.810
# epoch: 22, loss: 0.532, train_acc: 0.782, val_acc: 0.866
# epoch: 23, loss: 0.539, train_acc: 0.784, val_acc: 0.861
# epoch: 24, loss: 0.553, train_acc: 0.779, val_acc: 0.833
# epoch: 25, loss: 0.514, train_acc: 0.798, val_acc: 0.856
# epoch: 26, loss: 0.515, train_acc: 0.804, val_acc: 0.880
# epoch: 27, loss: 0.507, train_acc: 0.791, val_acc: 0.875
# epoch: 28, loss: 0.465, train_acc: 0.818, val_acc: 0.829
# epoch: 29, loss: 0.474, train_acc: 0.816, val_acc: 0.866
# epoch: 30, loss: 0.451, train_acc: 0.826, val_acc: 0.838
# epoch: 31, loss: 0.496, train_acc: 0.814, val_acc: 0.884
# epoch: 32, loss: 0.473, train_acc: 0.827, val_acc: 0.875
# epoch: 33, loss: 0.451, train_acc: 0.821, val_acc: 0.875
# epoch: 34, loss: 0.433, train_acc: 0.828, val_acc: 0.866
# epoch: 35, loss: 0.400, train_acc: 0.861, val_acc: 0.861
# epoch: 36, loss: 0.436, train_acc: 0.843, val_acc: 0.880
# epoch: 37, loss: 0.381, train_acc: 0.855, val_acc: 0.903
# epoch: 38, loss: 0.400, train_acc: 0.845, val_acc: 0.884
# epoch: 39, loss: 0.410, train_acc: 0.844, val_acc: 0.917
# epoch: 40, loss: 0.404, train_acc: 0.862, val_acc: 0.894
# epoch: 41, loss: 0.384, train_acc: 0.863, val_acc: 0.903
# epoch: 42, loss: 0.367, train_acc: 0.859, val_acc: 0.921
# epoch: 43, loss: 0.367, train_acc: 0.866, val_acc: 0.880
# epoch: 44, loss: 0.357, train_acc: 0.874, val_acc: 0.907
# epoch: 45, loss: 0.344, train_acc: 0.868, val_acc: 0.907
# epoch: 46, loss: 0.351, train_acc: 0.870, val_acc: 0.903
# epoch: 47, loss: 0.329, train_acc: 0.884, val_acc: 0.926
# epoch: 48, loss: 0.337, train_acc: 0.874, val_acc: 0.921
# epoch: 49, loss: 0.330, train_acc: 0.878, val_acc: 0.921
# epoch: 50, loss: 0.326, train_acc: 0.891, val_acc: 0.917
# epoch: 51, loss: 0.325, train_acc: 0.878, val_acc: 0.935
# epoch: 52, loss: 0.304, train_acc: 0.892, val_acc: 0.917
# epoch: 53, loss: 0.292, train_acc: 0.897, val_acc: 0.907
# epoch: 54, loss: 0.290, train_acc: 0.897, val_acc: 0.912
# epoch: 55, loss: 0.282, train_acc: 0.903, val_acc: 0.907
# epoch: 56, loss: 0.276, train_acc: 0.909, val_acc: 0.926
# epoch: 57, loss: 0.266, train_acc: 0.903, val_acc: 0.926
# epoch: 58, loss: 0.265, train_acc: 0.903, val_acc: 0.940
# epoch: 59, loss: 0.260, train_acc: 0.913, val_acc: 0.944
# epoch: 60, loss: 0.273, train_acc: 0.900, val_acc: 0.921
# epoch: 61, loss: 0.257, train_acc: 0.905, val_acc: 0.884
# epoch: 62, loss: 0.233, train_acc: 0.918, val_acc: 0.954
# epoch: 63, loss: 0.263, train_acc: 0.911, val_acc: 0.944
# epoch: 64, loss: 0.248, train_acc: 0.914, val_acc: 0.940
# epoch: 65, loss: 0.243, train_acc: 0.913, val_acc: 0.935
# epoch: 66, loss: 0.236, train_acc: 0.908, val_acc: 0.852
# epoch: 67, loss: 0.216, train_acc: 0.920, val_acc: 0.935
# epoch: 68, loss: 0.215, train_acc: 0.926, val_acc: 0.935
# epoch: 69, loss: 0.231, train_acc: 0.918, val_acc: 0.944
# epoch: 70, loss: 0.234, train_acc: 0.913, val_acc: 0.921
# epoch: 71, loss: 0.220, train_acc: 0.923, val_acc: 0.940
# epoch: 72, loss: 0.208, train_acc: 0.928, val_acc: 0.931
# epoch: 73, loss: 0.203, train_acc: 0.932, val_acc: 0.931
# epoch: 74, loss: 0.196, train_acc: 0.932, val_acc: 0.940
# epoch: 75, loss: 0.197, train_acc: 0.936, val_acc: 0.931
# epoch: 76, loss: 0.201, train_acc: 0.932, val_acc: 0.935
# epoch: 77, loss: 0.211, train_acc: 0.928, val_acc: 0.949
# epoch: 78, loss: 0.178, train_acc: 0.946, val_acc: 0.894
# epoch: 79, loss: 0.165, train_acc: 0.947, val_acc: 0.949
# epoch: 80, loss: 0.233, train_acc: 0.919, val_acc: 0.940
# epoch: 81, loss: 0.175, train_acc: 0.939, val_acc: 0.931
# epoch: 82, loss: 0.162, train_acc: 0.949, val_acc: 0.926
# epoch: 83, loss: 0.167, train_acc: 0.944, val_acc: 0.944
# epoch: 84, loss: 0.150, train_acc: 0.949, val_acc: 0.931
# epoch: 85, loss: 0.167, train_acc: 0.945, val_acc: 0.949
# epoch: 86, loss: 0.166, train_acc: 0.938, val_acc: 0.949
# epoch: 87, loss: 0.164, train_acc: 0.945, val_acc: 0.931
# epoch: 88, loss: 0.149, train_acc: 0.945, val_acc: 0.931
# epoch: 89, loss: 0.151, train_acc: 0.951, val_acc: 0.940
# epoch: 90, loss: 0.144, train_acc: 0.950, val_acc: 0.917
# epoch: 91, loss: 0.136, train_acc: 0.952, val_acc: 0.944
# epoch: 92, loss: 0.135, train_acc: 0.952, val_acc: 0.940
# epoch: 93, loss: 0.133, train_acc: 0.954, val_acc: 0.944
# epoch: 94, loss: 0.144, train_acc: 0.948, val_acc: 0.949
# epoch: 95, loss: 0.139, train_acc: 0.947, val_acc: 0.963
# epoch: 96, loss: 0.122, train_acc: 0.961, val_acc: 0.940
# epoch: 97, loss: 0.133, train_acc: 0.955, val_acc: 0.954
# epoch: 98, loss: 0.127, train_acc: 0.961, val_acc: 0.954
# epoch: 99, loss: 0.168, train_acc: 0.949, val_acc: 0.949
# epoch: 100, loss: 0.131, train_acc: 0.962, val_acc: 0.954

# %%
test_loss = metrics.Mean(name="test_loss")
test_acc = metrics.SparseCategoricalAccuracy(name="test_acc")

test_loss.reset_state()
test_acc.reset_state()
val_step(x_test, t_test)

print(f"test_loss: {test_loss.result():.3f}, test_acc: {test_acc.result():.3f}")
# Out:
# test_loss: 0.000, test_acc: 0.000

# %%
plt.figure()  
plt.plot(loss_history)
plt.plot(acc_history)
plt.title('Loss and Accuracy of the model')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend(['Loss', 'Accuracy'])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

preds = model(x_test, training=False).numpy().argmax(axis=1)

print("Confusion Matrix:")
print(confusion_matrix(t_test, preds))

print("\nClassification Report:")
print(classification_report(t_test, preds, target_names=labels))
# Out:
# Confusion Matrix:
# [[135   9   0]
#  [  4 147   0]
#  [  1   2 143]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        paper       0.96      0.94      0.95       144
#     scissors       0.93      0.97      0.95       151
#         rock       1.00      0.98      0.99       146
#
#     accuracy                           0.96       441
#    macro avg       0.96      0.96      0.96       441
# weighted avg       0.96      0.96      0.96       441

# %%
probs = model(x_test, training=False).numpy()
conf = probs[np.arange(len(probs)), preds]
wrong = np.where(preds != t_test)[0]

top_wrong = wrong[np.argsort(-conf[wrong])[:9]]

plt.figure(figsize=(9,9))
for i, idx in enumerate(top_wrong):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[idx])
    plt.title(f"T:{labels[t_test[idx]]}\nP:{labels[preds[idx]]}")
    plt.axis("off")
plt.suptitle("Most Confident Wrong Predictions")
plt.show()

# %%
# Download latest version
path2 = kagglehub.dataset_download("glushko/rock-paper-scissors-dataset")


# Simple approach: ignore boxes, just resize whole images
X2, y2 = input_target_split(path2 + "/test", labels)

# small subset to keep it fair
X2, y2 = X2[:300], y2[:300]

preds2 = model(X2, training=False).numpy().argmax(axis=1)

print("Cross-dataset accuracy:",
      np.mean(preds2 == y2))
# Out:
# Cross-dataset accuracy: 0.4033333333333333

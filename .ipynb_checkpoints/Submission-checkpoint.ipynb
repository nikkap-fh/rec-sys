# %% [markdown]
# ## Advanced Seminar for Recognition System
# ##### Masashi Nakayama - Fall Semester 2025/26
# ### Jan Niklas Kappey (ID: 2568017)

# %% [markdown]
# **Create a linearly indistinguishable multi-class classification
# system using a multi-layer perceptron. Please present your
# findings, including any ingenuity you have used.**

# %%
import kagglehub
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, auc
from sklearn.model_selection import train_test_split

# Download latest version
path = kagglehub.dataset_download("drgfreeman/rockpaperscissors")

print("Path to dataset files:", path)
print(os.listdir(path))
# Out:
# 2026-01-21 11:39:46.923936: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-21 11:39:47.116432: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX512F AVX512_VNNI AVX512_BF16, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Path to dataset files: /home/nikla/.cache/kagglehub/datasets/drgfreeman/rockpaperscissors/versions/2
# ['scissors', 'rock', 'README_rpc-cv-images.txt', 'rps-cv-images', 'paper']

# %%
import tensorflow as tf
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# GPUs: []

# %%
labels = ['paper','scissors','rock']

# %%
data_augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# %%
from keras.saving import register_keras_serializable

@register_keras_serializable()
class CNN(Model):
    def __init__(self, hidden_dim=512, output_dim=3):
        super().__init__()
        self.l1 = Conv2D(64, (3, 3), activation='relu')
        self.l2 = MaxPooling2D((2, 2))
        self.l3 = Conv2D(32, (3, 3), activation='relu')
        self.l4 = MaxPooling2D((2, 2))
        self.l5 = Flatten()
        self.l6 = Dense(hidden_dim, activation='relu')
        self.l7 = Dense(output_dim, activation='softmax')

        # Define the layer sequence you intended to iterate through
        self.ls = [self.l1, self.l2, self.l3, self.l4, self.l5, self.l6, self.l7]

    def call(self, x, training=False):
        if training:
            x = data_augment(x)
        for layer in self.ls:
            x = layer(x)
        return x

# %%
def input_target_split(root_dir, labels, image_size=(128, 128)):
    dataset = []
    for class_id, label in enumerate(labels):
        folder = os.path.join(root_dir, label)
        if not os.path.isdir(folder):
            raise FileNotFoundError(
                f"Couldn't find folder: {folder}\n"
                f"Check your dataset path. Top-level contents: {os.listdir(root_dir)}"
            )

        for fname in os.listdir(folder):
            fpath = os.path.join(folder, fname)
            img = load_img(fpath, target_size=image_size)
            img = img_to_array(img).astype("float32") / 255.0
            dataset.append((img, class_id))

    X, y = zip(*dataset)
    return np.array(X, dtype="float32"), np.array(y, dtype="int32")

# %%
X, y = input_target_split(path,labels)

# %%
# train / val / test split
x_train, x_tmp, t_train, t_tmp = train_test_split(
    X, y, test_size=0.3, random_state=1234, stratify=y)

x_val, x_test, t_val, t_test = train_test_split(
    x_tmp, t_tmp, test_size=0.67, random_state=1234, stratify=t_tmp)

# %%
n = len(labels)
model = CNN(hidden_dim=12, output_dim=n)

# IMPORTANT: use sparse loss/acc since labels are integers
criterion = losses.SparseCategoricalCrossentropy()
optimizer = optimizers.SGD(learning_rate=0.01)

train_loss = metrics.Mean(name="train_loss")
train_acc = metrics.SparseCategoricalAccuracy(name="train_acc")
val_acc = metrics.SparseCategoricalAccuracy(name="val_acc")

# %%
def compute_loss(t, y):
    return criterion(t, y)

@tf.function
def train_step(x, t):
    with tf.GradientTape() as tape:
        preds = model(x, training=True)
        loss = criterion(t, preds)
    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    train_loss.update_state(loss)
    train_acc.update_state(t, preds)
    return loss

@tf.function
def test_step(x, t):
    preds = model(x, training=False)
    loss = criterion(t, preds)
    test_loss.update_state(loss)
    test_acc.update_state(t, preds)
    return loss
    
@tf.function
def val_step(x, t):
    preds = model(x, training=False)
    val_acc.update_state(t, preds)

# %%
model.summary()
# Out:
# Model: "cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 100
batch_size = 16
n_batches = x_train.shape[0] // batch_size

loss_history = []
acc_history = []
val_acc_history = []


for epoch in range(epochs):
    # reset metrics EACH epoch (otherwise they accumulate across epochs)
    train_loss.reset_state()
    train_acc.reset_state()

    x_, t_ = shuffle(x_train, t_train, random_state=epoch)

    for batch in range(n_batches):
        start = batch * batch_size
        end = start + batch_size
        train_step(x_[start:end], t_[start:end])
        
    loss_history.append(train_loss.result().numpy())
    acc_history.append(train_acc.result().numpy())

    val_acc.reset_state()
    val_step(x_val, t_val)
    val_acc_history.append(val_acc.result().numpy())

    print(
    f"epoch: {epoch+1}, "
    f"loss: {train_loss.result():.3f}, "
    f"train_acc: {train_acc.result():.3f}, "
    f"val_acc: {val_acc.result():.3f}"
)
# Out:
# epoch: 1, loss: 1.096, train_acc: 0.366, val_acc: 0.394
# epoch: 2, loss: 1.061, train_acc: 0.467, val_acc: 0.394
# epoch: 3, loss: 0.959, train_acc: 0.581, val_acc: 0.676
# epoch: 4, loss: 0.851, train_acc: 0.644, val_acc: 0.745
# epoch: 5, loss: 0.805, train_acc: 0.672, val_acc: 0.759
# epoch: 6, loss: 0.774, train_acc: 0.675, val_acc: 0.769
# epoch: 7, loss: 0.713, train_acc: 0.716, val_acc: 0.755
# epoch: 8, loss: 0.706, train_acc: 0.702, val_acc: 0.796
# epoch: 9, loss: 0.682, train_acc: 0.725, val_acc: 0.792
# epoch: 10, loss: 0.631, train_acc: 0.758, val_acc: 0.782
# epoch: 11, loss: 0.604, train_acc: 0.762, val_acc: 0.694
# epoch: 12, loss: 0.602, train_acc: 0.775, val_acc: 0.815
# epoch: 13, loss: 0.597, train_acc: 0.772, val_acc: 0.810
# epoch: 14, loss: 0.536, train_acc: 0.798, val_acc: 0.829
# epoch: 15, loss: 0.528, train_acc: 0.797, val_acc: 0.843
# epoch: 16, loss: 0.512, train_acc: 0.812, val_acc: 0.870
# epoch: 17, loss: 0.506, train_acc: 0.820, val_acc: 0.880
# epoch: 18, loss: 0.481, train_acc: 0.824, val_acc: 0.894
# epoch: 19, loss: 0.474, train_acc: 0.826, val_acc: 0.741
# epoch: 20, loss: 0.463, train_acc: 0.830, val_acc: 0.889
# epoch: 21, loss: 0.454, train_acc: 0.835, val_acc: 0.921
# epoch: 22, loss: 0.443, train_acc: 0.827, val_acc: 0.926
# epoch: 23, loss: 0.410, train_acc: 0.845, val_acc: 0.921
# epoch: 24, loss: 0.408, train_acc: 0.839, val_acc: 0.931
# epoch: 25, loss: 0.365, train_acc: 0.870, val_acc: 0.889
# epoch: 26, loss: 0.351, train_acc: 0.874, val_acc: 0.921
# epoch: 27, loss: 0.336, train_acc: 0.878, val_acc: 0.921
# epoch: 28, loss: 0.299, train_acc: 0.901, val_acc: 0.898
# epoch: 29, loss: 0.306, train_acc: 0.886, val_acc: 0.944
# epoch: 30, loss: 0.302, train_acc: 0.886, val_acc: 0.912
# epoch: 31, loss: 0.280, train_acc: 0.895, val_acc: 0.944
# epoch: 32, loss: 0.259, train_acc: 0.911, val_acc: 0.940
# epoch: 33, loss: 0.274, train_acc: 0.910, val_acc: 0.843
# epoch: 34, loss: 0.257, train_acc: 0.907, val_acc: 0.935
# epoch: 35, loss: 0.226, train_acc: 0.926, val_acc: 0.894
# epoch: 36, loss: 0.259, train_acc: 0.911, val_acc: 0.940
# epoch: 37, loss: 0.221, train_acc: 0.919, val_acc: 0.912
# epoch: 38, loss: 0.229, train_acc: 0.919, val_acc: 0.954
# epoch: 39, loss: 0.217, train_acc: 0.917, val_acc: 0.875
# epoch: 40, loss: 0.205, train_acc: 0.926, val_acc: 0.944
# epoch: 41, loss: 0.181, train_acc: 0.935, val_acc: 0.944
# epoch: 42, loss: 0.198, train_acc: 0.930, val_acc: 0.949
# epoch: 43, loss: 0.177, train_acc: 0.936, val_acc: 0.949
# epoch: 44, loss: 0.181, train_acc: 0.936, val_acc: 0.954
# epoch: 45, loss: 0.211, train_acc: 0.933, val_acc: 0.958
# epoch: 46, loss: 0.179, train_acc: 0.938, val_acc: 0.954
# epoch: 47, loss: 0.167, train_acc: 0.944, val_acc: 0.935
# epoch: 48, loss: 0.169, train_acc: 0.943, val_acc: 0.940
# epoch: 49, loss: 0.160, train_acc: 0.940, val_acc: 0.940
# epoch: 50, loss: 0.141, train_acc: 0.951, val_acc: 0.935
# epoch: 51, loss: 0.261, train_acc: 0.912, val_acc: 0.935
# epoch: 52, loss: 0.176, train_acc: 0.935, val_acc: 0.926
# epoch: 53, loss: 0.163, train_acc: 0.938, val_acc: 0.912
# epoch: 54, loss: 0.155, train_acc: 0.950, val_acc: 0.949
# epoch: 55, loss: 0.162, train_acc: 0.943, val_acc: 0.954
# epoch: 56, loss: 0.139, train_acc: 0.952, val_acc: 0.963
# epoch: 57, loss: 0.141, train_acc: 0.949, val_acc: 0.958
# epoch: 58, loss: 0.140, train_acc: 0.947, val_acc: 0.889
# epoch: 59, loss: 0.133, train_acc: 0.949, val_acc: 0.972
# epoch: 60, loss: 0.125, train_acc: 0.955, val_acc: 0.968
# epoch: 61, loss: 0.132, train_acc: 0.954, val_acc: 0.954
# epoch: 62, loss: 0.114, train_acc: 0.960, val_acc: 0.958
# epoch: 63, loss: 0.113, train_acc: 0.957, val_acc: 0.977
# epoch: 64, loss: 0.115, train_acc: 0.960, val_acc: 0.972
# epoch: 65, loss: 0.115, train_acc: 0.959, val_acc: 0.958
# epoch: 66, loss: 0.134, train_acc: 0.950, val_acc: 0.912
# epoch: 67, loss: 0.112, train_acc: 0.963, val_acc: 0.972
# epoch: 68, loss: 0.094, train_acc: 0.965, val_acc: 0.963
# epoch: 69, loss: 0.120, train_acc: 0.952, val_acc: 0.986
# epoch: 70, loss: 0.089, train_acc: 0.970, val_acc: 0.972
# epoch: 71, loss: 0.102, train_acc: 0.965, val_acc: 0.954
# epoch: 72, loss: 0.102, train_acc: 0.962, val_acc: 0.963
# epoch: 73, loss: 0.104, train_acc: 0.968, val_acc: 0.968
# epoch: 74, loss: 0.086, train_acc: 0.968, val_acc: 0.972
# epoch: 75, loss: 0.076, train_acc: 0.971, val_acc: 0.963
# epoch: 76, loss: 0.078, train_acc: 0.973, val_acc: 0.963
# epoch: 77, loss: 0.070, train_acc: 0.974, val_acc: 0.972
# epoch: 78, loss: 0.095, train_acc: 0.962, val_acc: 0.968
# epoch: 79, loss: 0.095, train_acc: 0.968, val_acc: 0.963
# epoch: 80, loss: 0.096, train_acc: 0.969, val_acc: 0.972
# epoch: 81, loss: 0.079, train_acc: 0.974, val_acc: 0.963
# epoch: 82, loss: 0.100, train_acc: 0.966, val_acc: 0.958
# epoch: 83, loss: 0.080, train_acc: 0.972, val_acc: 0.963
# epoch: 84, loss: 0.068, train_acc: 0.978, val_acc: 0.963
# epoch: 85, loss: 0.076, train_acc: 0.972, val_acc: 0.981
# epoch: 86, loss: 0.116, train_acc: 0.957, val_acc: 0.968
# epoch: 87, loss: 0.089, train_acc: 0.964, val_acc: 0.972
# epoch: 88, loss: 0.089, train_acc: 0.969, val_acc: 0.968
# epoch: 89, loss: 0.084, train_acc: 0.971, val_acc: 0.963
# epoch: 90, loss: 0.091, train_acc: 0.967, val_acc: 0.968
# epoch: 91, loss: 0.060, train_acc: 0.978, val_acc: 0.972
# epoch: 92, loss: 0.072, train_acc: 0.968, val_acc: 0.968
# epoch: 93, loss: 0.076, train_acc: 0.968, val_acc: 0.986
# epoch: 94, loss: 0.074, train_acc: 0.974, val_acc: 0.912
# epoch: 95, loss: 0.083, train_acc: 0.966, val_acc: 0.977
# epoch: 96, loss: 0.070, train_acc: 0.980, val_acc: 0.972
# epoch: 97, loss: 0.048, train_acc: 0.982, val_acc: 0.968
# epoch: 98, loss: 0.068, train_acc: 0.974, val_acc: 0.963
# epoch: 99, loss: 0.070, train_acc: 0.975, val_acc: 0.981
# epoch: 100, loss: 0.060, train_acc: 0.980, val_acc: 0.991

# %%
test_loss = metrics.Mean(name="test_loss")
test_acc = metrics.SparseCategoricalAccuracy(name="test_acc")

test_loss.reset_state()
test_acc.reset_state()
test_step(x_test, t_test)

print(f"test_loss: {test_loss.result():.3f}, test_acc: {test_acc.result():.3f}")
# Out:
# test_loss: 0.068, test_acc: 0.977

# %%
plt.plot(loss_history, label="Training Loss")
plt.plot(acc_history, label="Training Accuracy")
plt.plot(val_acc_history, label="Validation Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Value")
plt.title("Training and Validation Performance")
plt.legend()


plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

preds = model(x_test, training=False).numpy().argmax(axis=1)

print("Confusion Matrix:")
print(confusion_matrix(t_test, preds))

print("\nClassification Report:")
print(classification_report(t_test, preds, target_names=labels))
# Out:
# Confusion Matrix:
# [[137   6   1]
#  [  1 150   0]
#  [  1   1 144]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        paper       0.99      0.95      0.97       144
#     scissors       0.96      0.99      0.97       151
#         rock       0.99      0.99      0.99       146
#
#     accuracy                           0.98       441
#    macro avg       0.98      0.98      0.98       441
# weighted avg       0.98      0.98      0.98       441

# %%
# Download latest version
path2 = kagglehub.dataset_download("glushko/rock-paper-scissors-dataset")


# Simple approach: ignore boxes, just resize whole images
X2, y2 = input_target_split(path2 + "/test", labels)

# small subset to keep it fair
X2, y2 = X2[:300], y2[:300]

preds2 = model(X2, training=False).numpy().argmax(axis=1)
probs2 = model(X2, training=False).numpy()

print("Cross-dataset accuracy:",
      np.mean(preds2 == y2))
# Out:
# Cross-dataset accuracy: 0.5433333333333333

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.metrics import precision_recall_fscore_support

def autolabel(ax, rects, fmt="{:.2f}", fontsize=9, y_offset=6):
    for r in rects:
        h = r.get_height()
        ax.annotate(
            fmt.format(h),
            xy=(r.get_x() + r.get_width() / 2, h),
            xytext=(0, y_offset),
            textcoords="offset points",
            ha="center",
            va="bottom",
            fontsize=fontsize,
            clip_on=False,   # <-- prevents clipping
        )



# ---------------------------
# 1) Make sure you have preds
# ---------------------------
# preds = model(x_test, training=False).numpy().argmax(axis=1)

# If your ground truth is one-hot, convert to class ids
t_true = np.argmax(t_test, axis=1) if getattr(t_test, "ndim", 1) > 1 else np.asarray(t_test)

# Labels list like: labels = ["cat", "dog", ...]
labels = list(labels)

# ---------------------------
# 2) Output directory
# ---------------------------
OUT_DIR = "eval_figures"
os.makedirs(OUT_DIR, exist_ok=True)

def savefig(path, dpi=200):
    plt.tight_layout()
    plt.savefig(path, dpi=dpi, bbox_inches="tight")
    plt.close()

# ---------------------------
# 3) Confusion matrices
# ---------------------------
cm = confusion_matrix(t_true, preds)
cm_norm = confusion_matrix(t_true, preds, normalize="true")

# Raw confusion matrix
fig, ax = plt.subplots(figsize=(7, 7))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(ax=ax, cmap="Blues", xticks_rotation=45, colorbar=True, values_format="d")
ax.set_title("Confusion Matrix (Counts)")
savefig(os.path.join(OUT_DIR, "confusion_matrix_counts.png"))

# Normalized confusion matrix
fig, ax = plt.subplots(figsize=(7, 7))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=labels)
disp.plot(ax=ax, cmap="Blues", xticks_rotation=45, colorbar=True, values_format=".2f")
ax.set_title("Confusion Matrix (Normalized by True Class)")
savefig(os.path.join(OUT_DIR, "confusion_matrix_normalized.png"))

# ---------------------------
# 4) Classification report (text) + bar charts
# ---------------------------
report = classification_report(t_true, preds, target_names=labels, digits=4)
print("Classification Report:\n", report)

with open(os.path.join(OUT_DIR, "classification_report.txt"), "w") as f:
    f.write(report)

prec, rec, f1, support = precision_recall_fscore_support(t_true, preds, labels=np.arange(len(labels)), zero_division=0)

x = np.arange(len(labels))

# Precision/Recall/F1 bar chart
fig, ax = plt.subplots(figsize=(10, 5))

bars_p = ax.bar(x - 0.25, prec, width=0.25, label="Precision")
bars_r = ax.bar(x,         rec,  width=0.25, label="Recall")
bars_f = ax.bar(x + 0.25,  f1,   width=0.25, label="F1")

ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha="right")
ax.set_ylim(0, 1.05)
ax.set_title("Per-class Precision / Recall / F1")
ax.legend()

autolabel(ax, bars_p, fmt="{:.2f}")
autolabel(ax, bars_r, fmt="{:.2f}")
autolabel(ax, bars_f, fmt="{:.2f}")

savefig(os.path.join(OUT_DIR, "per_class_prf.png"))

# Support bar chart
fig, ax = plt.subplots(figsize=(10, 4))

bars_s = ax.bar(x, support)
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha="right")
ax.set_title("Support (Samples per Class)")
ax.set_ylim(0, 170)

for r in bars_s:
    height = r.get_height()
    ax.annotate(
        f"{int(height)}",
        xy=(r.get_x() + r.get_width() / 2, height),
        xytext=(0, 3),
        textcoords="offset points",
        ha="center",
        va="bottom",
        fontsize=9
    )

savefig(os.path.join(OUT_DIR, "per_class_support.png"))

# ---------------------------
# 5) Optional: show most confused pairs
# ---------------------------
cm_offdiag = cm.copy()
np.fill_diagonal(cm_offdiag, 0)
pairs = np.dstack(np.unravel_index(np.argsort(cm_offdiag.ravel())[::-1], cm_offdiag.shape))[0]

top_k = 10
print("\nTop confused class pairs (true -> predicted):")
count = 0
for i, j in pairs:
    if cm_offdiag[i, j] == 0:
        break
    print(f"  {labels[i]} -> {labels[j]} : {cm_offdiag[i, j]}")
    count += 1
    if count >= top_k:
        break

# ---------------------------
# 6) Most confident wrong predictions (image gallery)
# ---------------------------

# Get full probability outputs
probs = model(x_test, training=False).numpy()

# Confidence of the predicted class
conf = probs[np.arange(len(probs)), preds]

# Handle one-hot vs integer ground truth
t_true = np.argmax(t_test, axis=1) if getattr(t_test, "ndim", 1) > 1 else np.asarray(t_test)

# Indices of wrong predictions
wrong = np.where(preds != t_true)[0]

if len(wrong) == 0:
    print("No misclassifications found.")
else:
    # Take top-N most confident wrong predictions
    top_wrong = wrong[np.argsort(-conf[wrong])[:9]]

    plt.figure(figsize=(9, 9))
    for i, idx in enumerate(top_wrong):
        plt.subplot(3, 3, i + 1)

        img = x_test[idx]
        if img.ndim == 2 or (img.ndim == 3 and img.shape[-1] == 1):
            plt.imshow(img.squeeze(), cmap="gray")
        else:
            plt.imshow(img)

        plt.title(
            f"T: {labels[t_true[idx]]}\n"
            f"P: {labels[preds[idx]]}\n"
            f"Conf: {conf[idx]:.2f}",
            fontsize=9
        )
        plt.axis("off")

    plt.suptitle("Most Confident Wrong Predictions", fontsize=14)

    save_path = os.path.join(OUT_DIR, "most_confident_wrong_predictions.png")
    savefig(save_path)

    print(f"Saved: {save_path}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        paper     0.9856    0.9514    0.9682       144
#     scissors     0.9554    0.9934    0.9740       151
#         rock     0.9931    0.9863    0.9897       146
#
#     accuracy                         0.9773       441
#    macro avg     0.9780    0.9770    0.9773       441
# weighted avg     0.9778    0.9773    0.9773       441
#
#
# Top confused class pairs (true -> predicted):
#   paper -> scissors : 6
#   paper -> rock : 1
#   rock -> scissors : 1
#   scissors -> paper : 1
#   rock -> paper : 1
# Saved: eval_figures/most_confident_wrong_predictions.png

# %%
# probs/preds
probs = model(x_test, training=False).numpy()
preds = probs.argmax(axis=1)

# ground-truth labels: supports int labels OR one-hot
t_true = np.argmax(t_test, axis=1) if getattr(t_test, "ndim", 1) > 1 else np.asarray(t_test)


top_k = 3
n_classes = len(labels)

# Choose ONE of these two filters:
# A) Top-K most confident CORRECT predictions per class (recommended)
use_correct_only = True

top_indices_per_class = {}

for c in range(n_classes):
    if use_correct_only:
        idx = np.where((t_true == c) & (preds == c))[0]
    else:
        # B) Top-K most confident predictions that the model PREDICTS as class c
        idx = np.where(preds == c)[0]

    if len(idx) == 0:
        top_indices_per_class[c] = np.array([], dtype=int)
        continue

    conf_c = probs[idx, c]  # model confidence for class c
    top = idx[np.argsort(-conf_c)[:top_k]]
    top_indices_per_class[c] = top

# Plot: 3 images per class (rows=classes, cols=top_k)
fig, axes = plt.subplots(n_classes, top_k, figsize=(top_k * 3.2, n_classes * 3.2))
if n_classes == 1:
    axes = np.array([axes])

for c in range(n_classes):
    for j in range(top_k):
        ax = axes[c, j] if n_classes > 1 else axes[j]
        if j >= len(top_indices_per_class[c]):
            ax.axis("off")
            continue

        i = top_indices_per_class[c][j]
        img = x_test[i]

        if img.ndim == 2 or (img.ndim == 3 and img.shape[-1] == 1):
            ax.imshow(img.squeeze(), cmap="gray")
        else:
            ax.imshow(img)

        ax.set_title(
            f"{labels[c]}\nconf={probs[i,c]:.2f}",
            fontsize=10
        )
        ax.axis("off")

plt.suptitle(f"Top-{top_k} Highest-Confidence Examples per Class"
             + (" (Correct Only)" if use_correct_only else " (Predicted Class)"),
             fontsize=14)

save_path = os.path.join(OUT_DIR, f"top_{top_k}_per_class.png")
savefig(save_path)
print("Saved:", save_path)
# Out:
# Saved: eval_figures/top_3_per_class.png

# %%
# -----------------------
# Raw confusion matrix
# -----------------------
cm = confusion_matrix(y2, preds2)

fig, ax = plt.subplots(figsize=(7, 7))
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=labels
)
disp.plot(
    ax=ax,
    cmap="Blues",
    xticks_rotation=45,
    colorbar=True,
    values_format="d"
)
ax.set_title("Generalization Confusion Matrix (Counts)")

plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "path2_confusion_matrix_counts.png"),
            dpi=200, bbox_inches="tight")
plt.show()

# -----------------------
# Normalized confusion matrix
# -----------------------
cm_norm = confusion_matrix(y2, preds2, normalize="true")

fig, ax = plt.subplots(figsize=(7, 7))
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_norm,
    display_labels=labels
)
disp.plot(
    ax=ax,
    cmap="Blues",
    xticks_rotation=45,
    colorbar=True,
    values_format=".2f"
)
ax.set_title("Generalization Confusion Matrix (Normalized by True Class)")

plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "path2_confusion_matrix_normalized.png"),
            dpi=200, bbox_inches="tight")
plt.show()

# %%
conf2  = probs2[np.arange(len(probs2)), preds2]

wrong = np.where(preds2 != y2)[0]
print("num wrong:", len(wrong))

if len(wrong) > 0:
    top_wrong = wrong[np.argsort(-conf2[wrong])[:9]]

    plt.figure(figsize=(9, 9))
    for i, idx in enumerate(top_wrong):
        plt.subplot(3, 3, i + 1)
        plt.imshow(X2[idx])
        plt.title(f"T:{labels[y2[idx]]}\nP:{labels[preds2[idx]]}\nConf:{conf2[idx]:.2f}", fontsize=9)
        plt.axis("off")
    plt.suptitle("Generalization: Most Confident Wrong Predictions", fontsize=14)
    plt.tight_layout()
    plt.show()
else:
    print("No misclassifications found on this subset.")
# Out:
# num wrong: 137
